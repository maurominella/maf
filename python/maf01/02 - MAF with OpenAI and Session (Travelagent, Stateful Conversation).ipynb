# %% [markdown]
# Inspired by [python-agent-framework-basicagent.ipynb](https://github.com/microsoft/Agent-Framework-Samples/blob/main/00.ForBeginners/02-explore-agentic-frameworks/code_samples/python-agent-framework-basicagent.ipynb)

# %% [markdown]
# # Common Libraries and Global Variables

# %%
# Common Libraries
import os, sys
from dotenv import load_dotenv # requires python-dotenv
from IPython.display import Markdown, display

config_path = "../../../config" # explicit path to the config folder
sys.path.append(config_path)
from auth import acquire_bearer_token, StaticBearerTokenCredential
if not load_dotenv(f"{config_path}/credentials_my.env"):
    print("Environment variables not loaded, cell execution stopped")
else:
    print("Environment variables have been loaded ;-)")

# Global libraries - recall to declare them as "global" in the functions where they are assigned
openai_endpoint = ""
openai_key = ""
model_id = ""
# Out:
# Environment variables have been loaded ;-)

# %% [markdown]
# # Authentication & Environment setup

# %% [raw]
# def authentication_and_environmentsetup():
#     global bearer_token_cognitiveservices, bearer_token_azureai
#     bearer_token_cognitiveservices, user_cognitiveservices = acquire_bearer_token(
#         scope="https://cognitiveservices.azure.com/.default", # https://ai.azure.com/.default, https://cognitiveservices.azure.com/.default...
#         auth_method="default") # default, cli, device
#
#     bearer_token_azureai, _ = acquire_bearer_token(
#         scope="https://ai.azure.com/.default", # https://ai.azure.com/.default, https://cognitiveservices.azure.com/.default...
#         auth_method="default") # default, cli, device
#
#     print("Bearer token Cognitive Services:", bearer_token_cognitiveservices[:10], "...")
#     print("Bearer token Azure AI:", bearer_token_azureai[:10], "...")
#     print(f'User info Cognitive Services: {user_cognitiveservices["name"]}, upn: {user_cognitiveservices["upn"]}')
#     # bearer_token_cognitiveservices['raw_claims']
#
# authentication_and_environmentsetup()

# %% [markdown]
# # Initialization

# %%
def init():
    global openai_endpoint, openai_key, model_id
    
    openai_endpoint = os.getenv("GITHUB_ENDPOINT")
    openai_key = os.getenv("GITHUB_TOKEN")
    model_id = os.environ["GITHUB_MODEL_ID"]
    
init()

# %%
# 🎲 Tool Function: Random Destination Generator
# This function will be available to the agent as a tool
# The agent can call this function to get random vacation destinations
def get_random_destination() -> str:
    from random import randint
    """Get a random vacation destination.
    
    Returns:
        str: A randomly selected destination from our predefined list
    """
    # List of popular vacation destinations around the world
    destinations = [
        "Barcelona, Spain",
        "Paris, France", 
        "Berlin, Germany",
        "Tokyo, Japan",
        "Sydney, Australia",
        "New York, USA",
        "Cairo, Egypt",
        "Cape Town, South Africa",
        "Rio de Janeiro, Brazil",
        "Bali, Indonesia"
    ]
    # Return a random destination from the list
    return destinations[randint(0, len(destinations) - 1)]

get_random_destination()
# Out:
# 'New York, USA'

# %%
# 🔗 Create OpenAI Chat Client for GitHub Models
# This client connects to GitHub Models API (OpenAI-compatible endpoint)
# Environment variables required:
# - GITHUB_ENDPOINT: API endpoint URL (usually https://models.inference.ai.azure.com)
# - GITHUB_TOKEN: Your GitHub personal access token
# - GITHUB_MODEL_ID: Model to use (e.g., gpt-4o-mini, gpt-4o)


# 🤖 Import Microsoft Agent Framework Components
# ChatAgent: The main agent class for conversational AI
# OpenAIChatClient: Client for connecting to OpenAI-compatible APIs (including GitHub Models)

from agent_framework import Agent
from agent_framework.openai import OpenAIChatClient

openai_chat_client = OpenAIChatClient(
    base_url=openai_endpoint,
    api_key=openai_key, 
    model_id=model_id
)

# %%
# 🤖 Create the Travel Planning Agent
# This creates a conversational AI agent with specific capabilities:
# - client: The AI model client for generating responses
# - instructions: System prompt that defines the agent's personality and role
# - tools: List of functions the agent can call to perform actions

agent = Agent(
    client=openai_chat_client,
    instructions="You are a helpful AI Agent that can help plan vacations for customers at random destinations.",
    tools=[get_random_destination]  # Our random destination tool function
)

# %%
session = agent.create_session()

# %%
# 🚀 Run the Agent
# Send a message to the agent and get a response
# The agent will use its tools (get_random_destination) if needed

response = await agent.run("Plan me a day trip", session=session)

# %%
# 📖 Extract and Display the Travel Plan
# Get the last message from the conversation (agent's response)s
last_message = response.messages[-1]

# Extract the text content from the message
text_content = last_message.contents[0].text

# Display the formatted travel plan
print("🏖️ Travel plan:")
display(Markdown(text_content))
# Out:
# 🏖️ Travel plan:
# Let's plan a day trip to Rio de Janeiro, Brazil! Here’s a suggested itinerary:
#
# ### Morning:
# - **Breakfast at Confeitaria Colombo**: Start your day with a delicious breakfast at this historic café, known for its beautiful architecture and tasty pastries.
# - **Visit Christ the Redeemer**: After breakfast, head to the iconic Christ the Redeemer statue. Take the train up to Corcovado Mountain for stunning views of the city.
#
# ### Afternoon:
# - **Lunch at a Local Restaurant**: Enjoy traditional Brazilian cuisine at a local restaurant. Try the feijoada (black bean stew) or a seafood dish.
# - **Explore Sugarloaf Mountain**: After lunch, take the cable car to Sugarloaf Mountain. The panoramic views of Rio are breathtaking, especially on a clear day.
#
# ### Evening:
# - **Stroll through Ipanema Beach**: Spend some time relaxing on the beach or walking along the promenade. You can take a dip or just enjoy the atmosphere.
# - **Dinner in the Lapa District**: Head to Lapa for dinner at a samba restaurant. Enjoy live music while savoring local dishes and caipirinhas.
# - **Nightlife**: If you’re up for it, explore the vibrant nightlife in Lapa with its bars and samba clubs.
#
# ### Tips:
# - Bring sunblock and stay hydrated as Rio can get hot.
# - Consider taking a guided tour for a more informative experience at the main attractions.
#
# Enjoy your day trip in Rio de Janeiro!

# %%
response2 = await agent.run("I don't like that destination. Plan me another vacation.",session= session)

# %%
last_message = response2.messages[-1]
text_content = last_message.contents[0].text
print("Change plan:")
print(text_content)
# Out:
# Change plan:
# Let's plan a day trip to Paris, France! Here’s a suggested itinerary:
#
# ### Morning:
# - **Breakfast at a Parisian Café**: Start your day with a classic French breakfast of croissants and café au lait at a local café, like Café de Flore.
# - **Visit the Eiffel Tower**: After breakfast, head to the Eiffel Tower. You can take an elevator to the top for stunning views of the city.
#
# ### Afternoon:
# - **Lunch at Le Jardin des Tuileries**: Enjoy a leisurely lunch in the beautiful Tuileries Garden. You can grab a sandwich or pastry from a nearby café.
# - **Explore the Louvre Museum**: Spend your afternoon at the Louvre. Don't miss the Mona Lisa and the beautiful architecture of the museum itself.
#
# ### Evening:
# - **Stroll along the Seine River**: Take a sunset walk along the Seine River, enjoy the breeze, and take in the views of iconic bridges and buildings.
# - **Dinner in the Montmartre District**: Head to Montmartre for dinner at a cozy bistro. Try traditional French dishes and perhaps enjoy some local wine.
# - **Moulin Rouge Show**: If you're up for it, consider an evening show at the renowned Moulin Rouge for a taste of Parisian entertainment.
#
# ### Tips:
# - Wear comfortable shoes for walking around the city.
# - Consider purchasing tickets in advance for popular attractions to avoid long lines.
#
# Enjoy your magical day in Paris!
